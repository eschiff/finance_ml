# %%
import numpy as np
import asyncio
import pandas as pd
import sqlite3
import json
import pickle
from datetime import datetime, timedelta, date
from collections import namedtuple, defaultdict
from typing import Tuple
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from typing import List, Tuple, Dict
from sklearn.compose import ColumnTransformer
import warnings
import plotly.express as px
import plotly.graph_objects as go
from xgboost import XGBRegressor
from copy import deepcopy
import os
import sys
import copy
import yfinance_ez as yf

module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from finance_ml.variants.linear_model.main import main
from finance_ml.variants.linear_model.hyperparams import Hyperparams
from finance_ml.variants.linear_model.preprocessing import preprocess_data, preprocess_quarterly_data
from finance_ml.variants.linear_model.backtest import compute_performance
from finance_ml.utils.constants import (
    QuarterlyColumns as QC, StockPupColumns, STOCKPUP_TABLE_NAME, QUARTERLY_DB_FILE_PATH,
    YF_QUARTERLY_TABLE_NAME, INDEX_COLUMNS, MISSING_SECTOR, MISSING_INDUSTRY,
    STOCK_GENERAL_INFO_CSV, FORMULAE, Q_DELTA_PREFIX, YOY_DELTA_PREFIX,
    QUARTER, YEAR, VS_MKT_IDX, CATEGORICAL_COLUMNS, TICKER_SYMBOL
)

warnings.simplefilter(action='ignore', category=FutureWarning)

pd.set_option('display.max_columns', None)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
hp = Hyperparams()

df, prediction_candidate_df = preprocess_data(hp)
# Out:
# /Users/ezras/projects/personal/finance_ml/finance_ml/variants/linear_model/preprocessing.py:156: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Initial combined data size: (64205, 37)
# Preprocessed quarterly df: (64205, 75)

# %%
portfolio = await compute_performance(df=df,
                          start_date=date(2020,1,1),
                          hyperparams=hp,
                          end_date=None)
# Out:
# Fitting data for: QuarterlyIndex  Q4 2019
# Filtering data between 4Q1999 and 4Q2019
# QuarterFilter removed 11269 rows. Output size: (49790, 73)
# Train Size: (39832, 72), Test Size: (9958, 72)
# [1]	valid_0's l1: 28.6246	valid_0's l2: 4255.03
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's l1: 28.4678	valid_0's l2: 4139.8
# [3]	valid_0's l1: 28.3202	valid_0's l2: 4039
# [4]	valid_0's l1: 28.2499	valid_0's l2: 4024.82
# [5]	valid_0's l1: 28.168	valid_0's l2: 3984.09
# [6]	valid_0's l1: 28.0979	valid_0's l2: 3932.1
# [7]	valid_0's l1: 28.0357	valid_0's l2: 3936.97
# [8]	valid_0's l1: 28.0055	valid_0's l2: 3927.71
# [9]	valid_0's l1: 27.9536	valid_0's l2: 3906.58
# [10]	valid_0's l1: 27.917	valid_0's l2: 3888.06
# [11]	valid_0's l1: 27.8914	valid_0's l2: 3845.64
# [12]	valid_0's l1: 27.8693	valid_0's l2: 3836.33
# [13]	valid_0's l1: 27.843	valid_0's l2: 3829.07
# [14]	valid_0's l1: 27.8223	valid_0's l2: 3820.51
# [15]	valid_0's l1: 27.7919	valid_0's l2: 3814.45
# [16]	valid_0's l1: 27.7801	valid_0's l2: 3806.78
# [17]	valid_0's l1: 27.76	valid_0's l2: 3791.9
# [18]	valid_0's l1: 27.7533	valid_0's l2: 3808.38
# [19]	valid_0's l1: 27.7387	valid_0's l2: 3787.29
# [20]	valid_0's l1: 27.7125	valid_0's l2: 3779.46
# [21]	valid_0's l1: 27.6995	valid_0's l2: 3772.47
# [83]	valid_0's l1: 27.9827	valid_0's l2: 8556.56
# [84]	valid_0's l1: 27.9807	valid_0's l2: 8565.71
# [85]	valid_0's l1: 27.969	valid_0's l2: 8562.32
# [86]	valid_0's l1: 27.9613	valid_0's l2: 8573.25
# [87]	valid_0's l1: 27.9598	valid_0's l2: 8546.18
# [88]	valid_0's l1: 27.964	valid_0's l2: 8545.16
# [89]	valid_0's l1: 27.9543	valid_0's l2: 8550.71
# [90]	valid_0's l1: 27.9376	valid_0's l2: 8528.76
# [91]	valid_0's l1: 27.9398	valid_0's l2: 8532.2
# [92]	valid_0's l1: 27.9371	valid_0's l2: 8538.55
# [93]	valid_0's l1: 27.9134	valid_0's l2: 8535.48
# [94]	valid_0's l1: 27.8908	valid_0's l2: 8517.08
# [95]	valid_0's l1: 27.8645	valid_0's l2: 8516.63
# [96]	valid_0's l1: 27.8703	valid_0's l2: 8517.73
# [97]	valid_0's l1: 27.8605	valid_0's l2: 8504.13
# [98]	valid_0's l1: 27.8576	valid_0's l2: 8505.07
# [99]	valid_0's l1: 27.8545	valid_0's l2: 8497.45
# [100]	valid_0's l1: 27.8557	valid_0's l2: 8505.83
# Did not meet early stopping. Best iteration is:
# [99]	valid_0's l1: 27.8545	valid_0's l2: 8497.45
# Filtering data between 4Q2020 and 1Q2021
# QuarterFilter removed 61059 rows. Output size: (0, 72)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-33d405a6b057> in async-def-wrapper()
#
# ~/projects/personal/finance_ml/finance_ml/variants/linear_model/backtest.py in compute_performance(df, start_date, hyperparams, end_date)
#      46         prediction_candidate_df = qtr_filter.transform(df.drop(columns=[TARGET_COLUMN]))
#      47
# ---> 48         y_pred = await metamodel.predict(prediction_candidate_df, adjust_for_current_price=False)
#      49         n_largest = y_pred.astype('float').nlargest(hyperparams.N_STOCKS_TO_BUY,
#      50                                                     columns=[TARGET_COLUMN])[TARGET_COLUMN]
#
# ~/projects/personal/finance_ml/finance_ml/variants/linear_model/metamodel.py in predict(self, df, adjust_for_current_price)
#      71             df_transformed.drop(columns=[QC.PRICE_AVG], inplace=True)
#      72
# ---> 73         predicted = self.model.predict(df_transformed)
#      74
#      75         # Grab random row from df and use its index columns
#
# ~/.pyenv/versions/3.7.0/lib/python3.7/site-packages/lightgbm/sklearn.py in predict(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     663                              % (self._n_features, n_features))
#     664         return self.booster_.predict(X, raw_score=raw_score, num_iteration=num_iteration,
# --> 665                                      pred_leaf=pred_leaf, pred_contrib=pred_contrib, **kwargs)
#     666
#     667     @property
#
# ~/.pyenv/versions/3.7.0/lib/python3.7/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    2413         return predictor.predict(data, num_iteration,
#    2414                                  raw_score, pred_leaf, pred_contrib,
# -> 2415                                  data_has_header, is_reshape)
#    2416
#    2417     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# ~/.pyenv/versions/3.7.0/lib/python3.7/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     502         if isinstance(data, Dataset):
#     503             raise TypeError("Cannot use Dataset instance for prediction, please use raw data instead")
# --> 504         data = _data_from_pandas(data, None, None, self.pandas_categorical)[0]
#     505         predict_type = C_API_PREDICT_NORMAL
#     506         if raw_score:
#
# ~/.pyenv/versions/3.7.0/lib/python3.7/site-packages/lightgbm/basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     313     if isinstance(data, DataFrame):
#     314         if len(data.shape) != 2 or data.shape[0] < 1:
# --> 315             raise ValueError('Input data must be 2 dimensional and non empty.')
#     316         if feature_name == 'auto' or feature_name is None:
#     317             data = data.rename(columns=str)
#
# ValueError: Input data must be 2 dimensional and non empty.

# %%
idx = pd.IndexSlice
df.loc[idx['AAPL', :, 2020]]
# Out:
#                              PriceAvg          Ebit  TotalStockholderEquity  \
# TickerSymbol Quarter Year
# AAPL         1       2020   73.568000  1.285300e+10            7.842500e+10
#              2       2020   76.406800  1.309100e+10            7.228200e+10
#              3       2020  107.487619  1.477500e+10            6.533900e+10
#              4       2020  118.476508  3.353400e+10            6.622400e+10
#
#                            DividendPerShare              Industry  Volatility  \
# TickerSymbol Quarter Year
# AAPL         1       2020          0.048125  Consumer Electronics    0.348521
#              2       2020          0.051250  Consumer Electronics    0.412398
#              3       2020          0.205000  Consumer Electronics    0.405721
#              4       2020          0.205000  Consumer Electronics    0.196495
#
#                            AssetsToLiabilitiesRatio  AvgPriceToEarningsRatio  \
# TickerSymbol Quarter Year
# AAPL         1       2020                  1.324104             7.324572e-09
#              2       2020                  1.294954             5.582844e-09
#              3       2020                  1.252714             8.481624e-09
#              4       2020                  1.230080             4.120205e-09
#
#                            DebtToEquityRatio  ReturnOnEquity  \
# TickerSymbol Quarter Year
# AAPL         1       2020           1.268448        0.171106
#              2       2020           1.405011        0.239921
#              3       2020           1.510078        0.247693
#              4       2020           1.499169        0.488765
#
#                            PriceToBookRatio  ProfitMargin  RnDtoRevenue  \
# TickerSymbol Quarter Year
# AAPL         1       2020          0.050048      0.192907      0.078284
#              2       2020          0.036781      0.188540      0.079719
#              3       2020          0.027661      0.195879      0.076942
#              4       2020          0.028035      0.258034      0.046330
#
#                            CashToRevenue  ExpensesToRevenue  Q_Delta_PriceAvg  \
# TickerSymbol Quarter Year
# AAPL         1       2020       0.688937           0.779586          0.158230
#              2       2020       0.559320           0.780665          0.038587
#              3       2020       0.587592           0.771631          0.406781
#              4       2020       0.323136           0.699082          0.102234
#
#                            Q_Delta_PriceHigh  Q_Delta_PriceLow  \
# TickerSymbol Quarter Year
# AAPL         1       2020           3.525309          0.030203
#              2       2020           0.121200          0.071818
#              3       2020           0.457567          0.496226
#              4       2020          -0.014776          0.204659
#
#                            Q_Delta_PriceEoQ  Q_Delta_Ebit  \
# TickerSymbol Quarter Year
# AAPL         1       2020         -0.198592     -0.497321
#              2       2020          0.527632      0.018517
#              3       2020          0.264172      0.128638
#              4       2020          0.177393      1.269645
#
#                            Q_Delta_GrossProfit  Q_Delta_TotalRevenue  \
# TickerSymbol Quarter Year
# AAPL         1       2020            -0.364795             -0.364914
#              2       2020             0.013858              0.023528
#              3       2020             0.088580              0.083991
#              4       2020             0.795455              0.722449
#
#                            Q_Delta_ResearchDevelopment  \
# TickerSymbol Quarter Year
# AAPL         1       2020                     0.025612
#              2       2020                     0.042278
#              3       2020                     0.046238
#              4       2020                     0.037164
#
#                            Q_Delta_TotalOperatingExpenses  \
# TickerSymbol Quarter Year
# AAPL         1       2020                       -0.313811
#              2       2020                        0.024945
#              3       2020                        0.071447
#              4       2020                        0.560503
#
#                            Q_Delta_IncomeBeforeTax  Q_Delta_IncomeTaxExpense  \
# TickerSymbol Quarter Year
# AAPL         1       2020                -0.493209                 -0.487778
#              2       2020                 0.000152                 -0.001060
#              3       2020                 0.134277                  0.182590
#              4       2020                 1.253473                  1.165171
#
#                            Q_Delta_OperatingIncome  Q_Delta_NetIncome  \
# TickerSymbol Quarter Year
# AAPL         1       2020                -0.497321          -0.494109
#              2       2020                 0.018517           0.000356
#              3       2020                 0.128638           0.126189
#              4       2020                 1.269645           1.268997
#
#                            Q_Delta_DividendsPaid  Q_Delta_RepurchaseOfStock  \
# TickerSymbol Quarter Year
# AAPL         1       2020              -0.046341                  -0.150509
#              2       2020               0.083259                  -0.064069
#              3       2020              -0.039661                  -0.937400
#              4       2020               0.029052                   0.571388
#
#                            Q_Delta_Depreciation  Q_Delta_IssuanceOfStock  \
# TickerSymbol Quarter Year
# AAPL         1       2020             -0.010653               213.000000
#              2       2020             -0.012204                 0.000000
#              3       2020             -0.018169                -0.934287
#              4       2020             -0.013323                 0.246667
#
#                            Q_Delta_Cash  Q_Delta_CommonStock  \
# TickerSymbol Quarter Year
# AAPL         1       2020      0.010133             0.044810
#              2       2020     -0.169040             0.013824
#              3       2020      0.138783            -0.934827
#              4       2020     -0.052767             0.019004
#
#                            Q_Delta_TotalAssets  Q_Delta_TotalLiab  \
# TickerSymbol Quarter Year
# AAPL         1       2020            -0.059357          -0.036290
#              2       2020            -0.009538           0.012758
#              3       2020             0.020621           0.055035
#              4       2020             0.093137           0.113251
#
#                            Q_Delta_LongTermDebt  Q_Delta_ShortLongTermDebt  \
# TickerSymbol Quarter Year
# AAPL         1       2020             -0.042889                   0.016432
#              2       2020              0.055699                  -0.277425
#              3       2020              0.049113                  -1.000000
#              4       2020              0.006223                        NaN
#
#                            Q_Delta_TotalStockholderEquity  Q_Delta_Volume  \
# TickerSymbol Quarter Year
# AAPL         1       2020                       -0.124046        0.396201
#              2       2020                       -0.078330        0.005093
#              3       2020                       -0.096054        1.922805
#              4       2020                        0.013545       -0.633754
#
#                            Q_Delta_Earnings  Q_Delta_RnDtoRevenue  \
# TickerSymbol Quarter Year
# AAPL         1       2020         -0.266111              0.614918
#              2       2020          0.362605              0.018319
#              3       2020         -0.074017             -0.034828
#              4       2020          1.268997             -0.397855
#
#                            Q_Delta_CashToRevenue  YOY_Delta_PriceAvg  \
# TickerSymbol Quarter Year
# AAPL         1       2020               0.590544            0.732642
#              2       2020              -0.188141            0.589722
#              3       2020               0.050547            1.078421
#              4       2020              -0.450066            0.865255
#
#                            YOY_Delta_PriceHigh  YOY_Delta_PriceLow  \
# TickerSymbol Quarter Year
# AAPL         1       2020             0.650665            0.575775
#              2       2020             0.755193            0.396862
#              3       2020             1.404437            0.878153
#              4       2020             6.286091            0.990239
#
#                            YOY_Delta_PriceEoQ  YOY_Delta_Ebit  \
# TickerSymbol Quarter Year
# AAPL         1       2020                 NaN       -6.672109
#              2       2020            0.804745        0.134009
#              3       2020            1.055837       -0.054400
#              4       2020            0.822218        0.311510
#
#                            YOY_Delta_GrossProfit  YOY_Delta_TotalRevenue  \
# TickerSymbol Quarter Year
# AAPL         1       2020                    NaN              600.164948
#              2       2020               0.121274                0.109201
#              3       2020               0.015465                0.010275
#              4       2020               0.258710                0.213681
#
#                            YOY_Delta_ResearchDevelopment  \
# TickerSymbol Quarter Year
# AAPL         1       2020                            NaN
#              2       2020                       0.117689
#              3       2020                       0.211192
#              4       2020                       0.159964
#
#                            YOY_Delta_TotalOperatingExpenses  \
# TickerSymbol Quarter Year
# AAPL         1       2020                               NaN
#              2       2020                          0.102425
#              3       2020                          0.031147
#              4       2020                          0.175925
#
#                            YOY_Delta_IncomeBeforeTax  \
# TickerSymbol Quarter Year
# AAPL         1       2020                        NaN
#              2       2020                   0.102930
#              3       2020                  -0.076022
#              4       2020                   0.295586
#
#                            YOY_Delta_IncomeTaxExpense  \
# TickerSymbol Quarter Year
# AAPL         1       2020                         NaN
#              2       2020                    0.009106
#              3       2020                   -0.087259
#              4       2020                    0.310158
#
#                            YOY_Delta_OperatingIncome  YOY_Delta_NetIncome  \
# TickerSymbol Quarter Year
# AAPL         1       2020                   0.462554            -0.026987
#              2       2020                   0.134009             0.120370
#              3       2020                  -0.054400            -0.074017
#              4       2020                   0.311510             0.293173
#
#                            YOY_Delta_DividendsPaid  \
# TickerSymbol Quarter Year
# AAPL         1       2020                -5.019311
#              2       2020                 0.007440
#              3       2020                 0.009198
#              4       2020                 0.020910
#
#                            YOY_Delta_RepurchaseOfStock  \
# TickerSymbol Quarter Year
# AAPL         1       2020                          NaN
#              2       2020                    -0.032775
#              3       2020                    -0.937670
#              4       2020                    -0.921791
#
#                            YOY_Delta_Depreciation  YOY_Delta_IssuanceOfStock  \
# TickerSymbol Quarter Year
# AAPL         1       2020                     NaN                        NaN
#              2       2020               -0.061712                 427.000000
#              3       2020               -0.150047                  -0.927885
#              4       2020               -0.053267                  16.531250
#
#                            YOY_Delta_Cash  YOY_Delta_CommonStock  \
# TickerSymbol Quarter Year
# AAPL         1       2020        0.008966              40.757198
#              2       2020       -0.339343               0.122778
#              3       2020       -0.221685              -0.929745
#              4       2020       -0.094566              -0.929653
#
#                            YOY_Delta_TotalAssets  YOY_Delta_TotalLiab  \
# TickerSymbol Quarter Year
# AAPL         1       2020              -0.063152             0.024719
#              2       2020              -0.015191             0.085387
#              3       2020              -0.043212             0.042419
#              4       2020               0.039446             0.146336
#
#                            YOY_Delta_LongTermDebt  \
# TickerSymbol Quarter Year
# AAPL         1       2020               -0.012361
#              2       2020                0.107281
#              3       2020                0.074722
#              4       2020                0.066643
#
#                            YOY_Delta_ShortLongTermDebt  \
# TickerSymbol Quarter Year
# AAPL         1       2020                          inf
#              2       2020                     -0.44497
#              3       2020                     -1.00000
#              4       2020                     -1.00000
#
#                            YOY_Delta_TotalStockholderEquity  YOY_Delta_Volume  \
# TickerSymbol Quarter Year
# AAPL         1       2020                         -0.259163               NaN
#              2       2020                         -0.250622          0.649412
#              3       2020                         -0.277926          4.915959
#              4       2020                         -0.260323          0.502197
#
#                            YOY_Delta_Earnings  YOY_Delta_RnDtoRevenue  \
# TickerSymbol Quarter Year
# AAPL         1       2020           -0.131217                     NaN
#              2       2020            0.216641                0.007652
#              3       2020           -0.430068                0.198874
#              4       2020            1.101052               -0.044260
#
#                            YOY_Delta_CashToRevenue  Q_Delta_PriceAvg_vs_^DJI  \
# TickerSymbol Quarter Year
# AAPL         1       2020                -0.998322                  2.712714
#              2       2020                -0.404385                 -0.211295
#              3       2020                -0.229601                  2.370764
#              4       2020                -0.253977                  1.564680
#
#                            YOY_Delta_PriceAvg_vs_^DJI  Volatility_vs_^DJI  \
# TickerSymbol Quarter Year
# AAPL         1       2020                    4.353237            4.039980
#              2       2020                   -5.912096            1.135617
#              3       2020                   27.561837            3.277298
#              4       2020                   10.856334            1.398268
#
#                            PredictedAppreciation
# TickerSymbol Quarter Year
# AAPL         1       2020                  75.16
#              2       2020                  68.63
#              3       2020                    NaN
#              4       2020                    NaN

# %%
def add_target_column(df: pd.DataFrame, hyperparams: Hyperparams) -> pd.DataFrame:
    """Adds a target column of predicted appreciation"""
    tickers = set(df.index.levels[TICKER_SYMBOL])

    new_df = pd.DataFrame()
    for ticker in tickers:
        ticker_df = df[df.index.isin([ticker], level=TICKER_SYMBOL)][[
            QC.PRICE_AVG, QC.DIVIDEND_PER_SHARE]]
        ticker_df = ticker_df.sort_index(level=YEAR, ascending=True)

        ticker_df["FuturePrice"] = ticker_df[QC.PRICE_AVG].shift(
            periods=-hyperparams.N_QUARTERS_OUT_TO_PREDICT)

        if hyperparams.INCLUDE_DIVIDENDS_IN_PREDICTED_PRICE:
            ticker_df["TotalDividendsPaid"] = df[QC.DIVIDEND_PER_SHARE].rolling(
                min_periods=1, window=hyperparams.N_QUARTERS_OUT_TO_PREDICT).sum().shift(
                1 - hyperparams.N_QUARTERS_OUT_TO_PREDICT).fillna(0)

            ticker_df["FuturePrice"] = ticker_df["FuturePrice"] + ticker_df["TotalDividendsPaid"]

        # Target column is predicted appreciation (as a percentage. 2.0 = 2% increase)
        ticker_df[TARGET_COLUMN] = round(
            100.0 * (ticker_df["FuturePrice"] - ticker_df[QC.PRICE_AVG]
                     ) / ticker_df[QC.PRICE_AVG], 2)
        new_df = new_df.append(ticker_df[[TARGET_COLUMN]])

    output = df.join(new_df)
    return output

df_aapl = df.loc[idx['AAPL', :, :]]
df_aapl.drop(columns=['PredictedAppreciation'], inplace=True)
add_target_column(df_aapl, hp)
# Out:
# /Users/ezras/.pyenv/versions/3.7.0/lib/python3.7/site-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-32da3a1cd66f> in <module>
#      30 df_aapl = df.loc[idx['AAPL', :, :]]
#      31 df_aapl.drop(columns=['PredictedAppreciation'], inplace=True)
# ---> 32 add_target_column(df_aapl, hp)
#
# <ipython-input-44-32da3a1cd66f> in add_target_column(df, hyperparams)
#       6     for ticker in tickers:
#       7         ticker_df = df[df.index.isin([ticker], level=TICKER_SYMBOL)][[
# ----> 8             QC.PRICE_AVG, QC.DIVIDEND_PER_SHARE]]
#       9         ticker_df = ticker_df.sort_index(level=YEAR, ascending=True)
#      10
#
# NameError: name 'QC' is not defined
